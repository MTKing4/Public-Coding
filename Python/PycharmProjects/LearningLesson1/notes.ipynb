# %%
import pandas as pd

df = pd.DataFrame({
    "Potatoes": [1, 3, 4],
    "Fingers": ["curl", "square", "straight"],
    "person": ["moe", "hoe", "stoe"]
})

new_df = df.style.relabel_index(["row 1", "row 2", "row 3"], axis=0)

new_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_ef521">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef521_level0_col0" class="col_heading level0 col0" >Potatoes</th>
#       <th id="T_ef521_level0_col1" class="col_heading level0 col1" >Fingers</th>
#       <th id="T_ef521_level0_col2" class="col_heading level0 col2" >person</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef521_level0_row0" class="row_heading level0 row0" >row 1</th>
#       <td id="T_ef521_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ef521_row0_col1" class="data row0 col1" >curl</td>
#       <td id="T_ef521_row0_col2" class="data row0 col2" >moe</td>
#     </tr>
#     <tr>
#       <th id="T_ef521_level0_row1" class="row_heading level0 row1" >row 2</th>
#       <td id="T_ef521_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_ef521_row1_col1" class="data row1 col1" >square</td>
# ...

# %%
import kagglehub
import pandas as pd
path = kagglehub.dataset_download("umitka/imdb-ratings")

print(path)


df = pd.read_csv("imdb_ratings.csv")

# new_df = df.style.format(precision=2)

# df.loc[df['title'].str.contains('love')]
df.loc[df['title'].str.contains('love')]
df.loc[(df['averageRating'] >= 9.9) & (df['numVotes'] > 100)]
# Out:
# ...
# C:\Users\Mohammad Tareq\.cache\kagglehub\datasets\umitka\imdb-ratings\versions\1
#        Unnamed: 0     titleId                                  title  \
# 39208       39208  tt11926728                         Days of Géants
# 42151       42151  tt12728950  The Wake-Up Call with Pritan Ambroase
# 43212       43213  tt12980094                      Days of Géants II
# 58102       58103   tt8560994                      Friday Five Sharp
#
#        averageRating  numVotes
# 39208           10.0       163
# 42151           10.0       723
# 43212            9.9       169
# 58102            9.9      2685
